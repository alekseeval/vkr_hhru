# %%
from services.db_service import *
vacancies = Vacancy.select()

# %%
print(vacancies[0].description)
# Out:
# ---------------------------------------------------------------------------
# InFailedSqlTransaction                    Traceback (most recent call last)
# c:\users\andrey\appdata\local\programs\python\python39\lib\site-packages\peewee.py in execute_sql(self, sql, params, commit)
#    3143             try:
# -> 3144                 cursor.execute(sql, params or ())
#    3145             except Exception:
#
# InFailedSqlTransaction: ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
#
# During handling of the above exception, another exception occurred:
#
# InternalError                             Traceback (most recent call last)
# <ipython-input-2-3dfd193c2dda> in <module>
# ----> 1 print(vacancies[0].description)
#       2
#
# c:\users\andrey\appdata\local\programs\python\python39\lib\site-packages\peewee.py in __getitem__(self, value)
#    1995
#    1996     def __getitem__(self, value):
# -> 1997         self._ensure_execution()
# ...

# %%
print(vacancies[0].id)
# Out:
# ---------------------------------------------------------------------------
# InFailedSqlTransaction                    Traceback (most recent call last)
# c:\users\andrey\appdata\local\programs\python\python39\lib\site-packages\peewee.py in execute_sql(self, sql, params, commit)
#    3143             try:
# -> 3144                 cursor.execute(sql, params or ())
#    3145             except Exception:
#
# InFailedSqlTransaction: ОШИБКА:  текущая транзакция прервана, команды до конца блока транзакции игнорируются
#
#
# During handling of the above exception, another exception occurred:
#
# InternalError                             Traceback (most recent call last)
# <ipython-input-2-888ec1f75bfc> in <module>
# ----> 1 print(vacancies[0].id)
#
# c:\users\andrey\appdata\local\programs\python\python39\lib\site-packages\peewee.py in __getitem__(self, value)
#    1995
#    1996     def __getitem__(self, value):
# -> 1997         self._ensure_execution()
# ...
