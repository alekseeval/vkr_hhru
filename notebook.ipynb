# %%
from data_parsers.hhParser import HhParser
parser = HhParser()

# %% [markdown]
# Загрузка статичных словарей предоставляемых API

# %%
parser.load_to_db_dictionaries()
# Out:
# ----> Into table schedule was inserted 5 values
# ----> Into table experience was inserted 4 values
# ----> Into table currency was inserted 10 values
# ----> Into table employment was inserted 5 values
# ----> Into table specialization was inserted 621 values
# ----> Into table vacancies_id was inserted 1 vacancies

# %% [markdown]
# Получение всех вакансий

# %%
parser.get_vacancies_from_all_pages()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\users\andrey\appdata\local\programs\python\python39\lib\site-packages\peewee.py in get(self, database)
#    6883         try:
# -> 6884             return clone.execute(database)[0]
#    6885         except IndexError:
#
# c:\users\andrey\appdata\local\programs\python\python39\lib\site-packages\peewee.py in __getitem__(self, item)
#    4274             self.fill_cache(item if item > 0 else 0)
# -> 4275             return self.row_cache[item]
#    4276         else:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# VacancyDoesNotExist                       Traceback (most recent call last)
# c:\users\andrey\appdata\local\programs\python\python39\lib\site-packages\peewee.py in get_or_create(cls, **kwargs)
#    6479                 try:
# -> 6480                     return query.get(), False
#    6481                 except cls.DoesNotExist:
#
# c:\users\andrey\appdata\local\programs\python\python39\lib\site-packages\peewee.py in get(self, database)
#    6886             sql, params = clone.sql()
# -> 6887             raise self.model.DoesNotExist('%s instance matching query does '
#    6888                                           'not exist:\nSQL: %s\nParams: %s' %
#
# VacancyDoesNotExist: <Model: Vacancy> instance matching query does not exist:
# SQL: SELECT "t1"."id", "t1"."name", "t1"."description", "t1"."area_id", "t1"."branded_description", "t1"."schedule", "t1"."accept_handicapped", "t1"."accept_kids", "t1"."accept_incomplete_resumes", "t1"."experience", "t1"."address_lat", "t1"."address_lng", "t1"."employment_id", "t1"."salary_from", "t1"."salary_to", "t1"."salary_currency_code", "t1"."salary_gross", "t1"."archived", "t1"."created_at", "t1"."published_at", "t1"."employer_id", "t1"."has_test", "t1"."premium", "t1"."vacancy_type", "t1"."vacancy_billing_type" FROM "vacancies" AS "t1" WHERE ((((((((((((((((((((((((("t1"."id" = %s) AND ("t1"."name" = %s)) AND ("t1"."description" = %s)) AND ("t1"."premium" = %s)) AND ("t1"."branded_description" IS %s)) AND ("t1"."accept_handicapped" = %s)) AND ("t1"."accept_kids" = %s)) AND ("t1"."accept_incomplete_resumes" = %s)) AND ("t1"."salary_from" = %s)) AND ("t1"."salary_to" = %s)) AND ("t1"."salary_gross" = %s)) AND ("t1"."archived" = %s)) AND ("t1"."created_at" = %s)) AND ("t1"."published_at" = %s)) AND ("t1"."employer_id" = %s)) AND ("t1"."has_test" = %s)) AND ("t1"."vacancy_type" = %s)) AND ("t1"."vacancy_billing_type" = %s)) AND ("t1"."area_id" = %s)) AND ("t1"."schedule" = %s)) AND ("t1"."experience" = %s)) AND ("t1"."address_lat" = %s)) AND ("t1"."address_lng" = %s)) AND ("t1"."employment_id" = %s)) AND ("t1"."salary_currency_code" = %s)) LIMIT %s OFFSET %s
# Params: ['43899415', 'Заведующий мебельным салоном', '<p>Мы - компания «Райтон Якутск». Являемся одним из ведущих филиалов международной компании «Райтон», которая занимается производством и продажей качественных товаров для сна (матрасов, кроватей, подушек и многого другого).</p> <p>По результатам продаж среди 170 фирменных салонов в России и СНГ мы 2 года подряд являемся чемпионом во всей международной сети – Москва, Санкт-Петербург, Астана, Минск стоят позади нас.</p> <p>Мы растем. Прежний руководитель фирменного салона был повышен в должности, поэтому появилось вакантное место на роль руководителя фирменного салона
#
# During handling of the above exception, another exception occurred:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-7-a37c769892c0> in <module>
# ----> 1 parser.get_vacancies_from_all_pages()
#
# ~\PycharmProjects\pythonProject2\data_parsers\hhParser.py in get_vacancies_from_all_pages(self, req_params)
#      76         bar = Bar(' -->Получение данных о вакансиях', max=len(data_book))
#      77         for data in data_book:
# ---> 78             vacancies_info.append(self.get_vacancy_info_by_id(data.get('id')))
#      79             bar.next()
#      80         bar.finish()
#
# ~\PycharmProjects\pythonProject2\services\db_service.py in save_vacancies(self, vacancies_list)
#     164                 b_type = {}
#     165
# --> 166             self.model.Vacancy.get_or_create(
#     167                 id=vacancy.get('id'),
#     168                 name=vacancy.get('name'),
#
# c:\users\andrey\appdata\local\programs\python\python39\lib\site-packages\peewee.py in get_or_create(cls, **kwargs)
#    6480                     return query.get(), False
#    6481                 except cls.DoesNotExist:
# -> 6482                     raise exc
#    6483
#    6484     @classmethod
#
# c:\users\andrey\appdata\local\programs\python\python39\lib\site-packages\peewee.py in get_or_create(cls, **kwargs)
#    6475                     kwargs.update(defaults)
#    6476                 with cls._meta.database.atomic():
# -> 6477                     return cls.create(**kwargs), True
#    6478             except IntegrityError as exc:
#    6479                 try:
#
# c:\users\andrey\appdata\local\programs\python\python39\lib\site-packages\peewee.py in create(cls, **query)
#    6344     def create(cls, **query):
#    6345         inst = cls(**query)
# -> 6346         inst.save(force_insert=True)
#    6347         return inst
#    6348
#
# c:\users\andrey\appdata\local\programs\python\python39\lib\site-packages\peewee.py in save(self, force_insert, only)
#    6554             rows = self.update(**field_dict).where(self._pk_expr()).execute()
#    6555         elif pk_field is not None:
# -> 6556             pk = self.insert(**field_dict).execute()
#    6557             if pk is not None and (self._meta.auto_increment or
#    6558                                    pk_value is None):
#
# c:\users\andrey\appdata\local\programs\python\python39\lib\site-packages\peewee.py in inner(self, database, *args, **kwargs)
#    1905             raise InterfaceError('Query must be bound to a database in order '
#    1906                                  'to call "%s".' % method.__name__)
# -> 1907         return method(self, database, *args, **kwargs)
#    1908     return inner
#    1909
#
# c:\users\andrey\appdata\local\programs\python\python39\lib\site-packages\peewee.py in execute(self, database)
#    1976     @database_required
#    1977     def execute(self, database):
# -> 1978         return self._execute(database)
#    1979
#    1980     def _execute(self, database):
#
# c:\users\andrey\appdata\local\programs\python\python39\lib\site-packages\peewee.py in _execute(self, database)
#    2743             self._returning = (self.table._primary_key,)
#    2744         try:
# -> 2745             return super(Insert, self)._execute(database)
#    2746         except self.DefaultValuesException:
#    2747             pass
#
# c:\users\andrey\appdata\local\programs\python\python39\lib\site-packages\peewee.py in _execute(self, database)
#    2470     def _execute(self, database):
#    2471         if self._returning:
# -> 2472             cursor = self.execute_returning(database)
#    2473         else:
#    2474             cursor = database.execute(self)
#
# c:\users\andrey\appdata\local\programs\python\python39\lib\site-packages\peewee.py in execute_returning(self, database)
#    2477     def execute_returning(self, database):
#    2478         if self._cursor_wrapper is None:
# -> 2479             cursor = database.execute(self)
#    2480             self._cursor_wrapper = self._get_cursor_wrapper(cursor)
#    2481         return self._cursor_wrapper
#
# c:\users\andrey\appdata\local\programs\python\python39\lib\site-packages\peewee.py in execute(self, query, commit, **context_options)
#    3155         ctx = self.get_sql_context(**context_options)
#    3156         sql, params = ctx.sql(query).query()
# -> 3157         return self.execute_sql(sql, params, commit=commit)
#    3158
#    3159     def get_context_options(self):
#
# c:\users\andrey\appdata\local\programs\python\python39\lib\site-packages\peewee.py in execute_sql(self, sql, params, commit)
#    3149             else:
#    3150                 if commit and not self.in_transaction():
# -> 3151                     self.commit()
#    3152         return cursor
#    3153
#
# c:\users\andrey\appdata\local\programs\python\python39\lib\site-packages\peewee.py in __exit__(self, exc_type, exc_value, traceback)
#    2915             new_type = self.exceptions[exc_type.__name__]
#    2916             exc_args = exc_value.args
# -> 2917             reraise(new_type, new_type(exc_value, *exc_args), traceback)
#    2918
#    2919
#
# c:\users\andrey\appdata\local\programs\python\python39\lib\site-packages\peewee.py in reraise(tp, value, tb)
#     188     def reraise(tp, value, tb=None):
#     189         if value.__traceback__ is not tb:
# --> 190             raise value.with_traceback(tb)
#     191         raise value
#     192
#
# c:\users\andrey\appdata\local\programs\python\python39\lib\site-packages\peewee.py in execute_sql(self, sql, params, commit)
#    3142             cursor = self.cursor(commit)
#    3143             try:
# -> 3144                 cursor.execute(sql, params or ())
#    3145             except Exception:
#    3146                 if self.autorollback and not self.in_transaction():
#
# IntegrityError: ОШИБКА:  повторяющееся значение ключа нарушает ограничение уникальности "vacancies_pkey"
# DETAIL:  Ключ "(id)=(43899415)" уже существует.
